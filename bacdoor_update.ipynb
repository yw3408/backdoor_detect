# %%
# %tensorflow_version 1.x

# %%
# %pylab inline

import os
import sys
import time
import h5py


import random
import tensorflow as tf
import logging
from tqdm import tqdm

from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator
from keras import backend as K

from keras.losses import categorical_crossentropy
from keras.metrics import categorical_accuracy
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.layers import UpSampling2D, Cropping2D

from decimal import Decimal
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
SEED = 123

random.seed(SEED)
np.random.seed(SEED)
# tf.random.set_seed(SEED)
tf.set_random_seed(SEED)

# %%
# input settings
DATA_DIR = '/content/drive/MyDrive/ML4Cyber/data'
DATA_FILE = 'clean_test_data.h5'
MODEL_DIR = '/content/drive/MyDrive/ML4Cyber/model'
# MODEL_FILE = 'sunglasses_bd_net.h5'
MODEL_FILE = 'anonymous_bd_net.h5'

# %%
def load_dataset(data_file, datatype='youtubeface', batchsize=64):
    print('loading data file:{}'.format(DATA_FILE))
    if datatype == 'im':
        dataset = {}
        keys=['X_test', 'Y_test']
        with h5py.File(data_file, 'r') as hf:
            for name in keys:
                dataset[name] = np.array(hf.get(name))
        x_data = np.array(dataset['X_test'], dtype='float32')
        y_data = np.array(dataset['Y_test'], dtype='float32')
        
    elif datatype == 'youtubeface':
        data = h5py.File(data_file, 'r')
        x_data = np.array(data['data'])
        y_data = np.array(data['label'])
        x_data = x_data.transpose((0,2,3,1))

    print('X_test shape %s' % str(x_data.shape))
    print('Y_test shape %s' % str(y_data.shape))
    # print('loading into dataloader')
    # datagen = ImageDataGenerator()
    # dataloader = datagen.flow(x_data, y_data, batch_size=batchsize)
    # sample_num = x_data.shape[0]
    # datashape = x_data.shape[1:]


    return x_data, y_data

# %%
x_data, y_data = load_dataset(os.path.join(DATA_DIR, DATA_FILE))
model = load_model(os.path.join(MODEL_DIR, MODEL_FILE))
print('loading model file: ', MODEL_FILE)
# Out:
# loading data file:clean_test_data.h5
# X_test shape (12830, 55, 47, 3)
# Y_test shape (12830,)
# loading model file:  anonymous_bd_net.h5

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 55, 47, 3)    0
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 52, 44, 20)   980         input[0][0]
# __________________________________________________________________________________________________
# pool_1 (MaxPooling2D)           (None, 26, 22, 20)   0           conv_1[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 24, 20, 40)   7240        pool_1[0][0]
# __________________________________________________________________________________________________
# pool_2 (MaxPooling2D)           (None, 12, 10, 40)   0           conv_2[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv2D)                 (None, 10, 8, 60)    21660       pool_2[0][0]
# __________________________________________________________________________________________________
# pool_3 (MaxPooling2D)           (None, 5, 4, 60)     0           conv_3[0][0]
# __________________________________________________________________________________________________
# conv_4 (Conv2D)                 (None, 4, 3, 80)     19280       pool_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1200)         0           pool_3[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 960)          0           conv_4[0][0]
# __________________________________________________________________________________________________
# fc_1 (Dense)                    (None, 160)          192160      flatten_1[0][0]
# __________________________________________________________________________________________________
# fc_2 (Dense)                    (None, 160)          153760      flatten_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 160)          0           fc_1[0][0]
#                                                                  fc_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 160)          0           add_1[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1283)         206563      activation_1[0][0]
# ==================================================================================================
# Total params: 601,643
# Trainable params: 601,643
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
logger = logging.getLogger(__name__)

class NeuralCleanse:

    def __init__(
        self,
        model,
        use_logits: bool = False,
        channels_first: bool = False,
        # clip_values: Optional["CLIP_VALUES_TYPE"] = None,
        # preprocessing_defences: Union["Preprocessor", List["Preprocessor"], None] = None,
        # postprocessing_defences: Union["Postprocessor", List["Postprocessor"], None] = None,
        # preprocessing: "PREPROCESSING_TYPE" = (0, 1),
        input_shape = [55, 47, 3],
        input_layer: int = 0,
        output_layer: int = 0,
        steps: int = 150,
        init_cost: float = 1e-3,
        norm = 1,
        learning_rate: float = 0.1,
        attack_success_threshold: float = 0.98,
        patience: int = 5,
        early_stop: bool = True,
        early_stop_threshold: float = 0.98,
        early_stop_patience: int = 10,
        cost_multiplier: float = 1.5,
        batch_size: int = 64,
        num_classes = 1283,
    ):

        self.model = model
        self.steps = steps
        self.init_cost = init_cost
        self.norm = norm
        self.learning_rate = learning_rate
        self.attack_success_threshold = attack_success_threshold
        self.patience = patience
        self.early_stop = early_stop
        self.early_stop_threshold = early_stop_threshold
        self.early_stop_patience = early_stop_patience
        self.cost_multiplier_up = cost_multiplier
        self.cost_multiplier_down = cost_multiplier ** 1.5
        self.batch_size = batch_size
        self.top_indices = []
        self.activation_threshold = 0
        self.num_classes = num_classes

        mask = np.random.uniform(size=input_shape)
        pattern = np.random.uniform(size=input_shape)
        self.epsilon = K.epsilon()

        # Normalize mask between [0, 1]
        self.mask_tensor_raw = K.variable(mask)
        # self.mask_tensor = K.expand_dims(K.tanh(self.mask_tensor_raw) / (2 - self.epsilon) + 0.5, axis=0)
        self.mask_tensor = K.tanh(self.mask_tensor_raw) / (2 - self.epsilon) + 0.5

        # Normalize pattern between [0, 1]
        self.pattern_tensor_raw = K.variable(pattern)
        self.pattern_tensor = K.expand_dims(K.tanh(self.pattern_tensor_raw) / (2 - self.epsilon) + 0.5, axis=0)

        reverse_mask_tensor = K.ones_like(self.mask_tensor) - self.mask_tensor
        input_tensor = K.placeholder(model.input_shape)
        x_adv_tensor = reverse_mask_tensor * input_tensor + self.mask_tensor * self.pattern_tensor

        output_tensor = self.model(x_adv_tensor)
        y_true_tensor = K.placeholder(model.outputs[0].shape.as_list())

        self.loss_acc = categorical_accuracy(output_tensor, y_true_tensor)
        self.loss_ce = categorical_crossentropy(output_tensor, y_true_tensor)

        if self.norm == 1:
            # TODO: change 3 to dynamically set img_color
            self.loss_reg = K.sum(K.abs(self.mask_tensor)) / 3
        elif self.norm == 2:
            self.loss_reg = K.sqrt(K.sum(K.square(self.mask_tensor)) / 3)



        self.cost = self.init_cost
        self.cost_tensor = K.variable(self.cost)
        self.loss_combined = self.loss_ce + self.loss_reg * self.cost_tensor
        self.opt = Adam(lr=self.learning_rate, beta_1=0.5, beta_2=0.9)
        # self.opt = optimizer

        self.updates = self.opt.get_updates(
            params=[self.pattern_tensor_raw, self.mask_tensor_raw], loss=self.loss_combined
        )
        self.train = K.function(
            [input_tensor, y_true_tensor],
            [self.loss_ce, self.loss_reg, self.loss_combined, self.loss_acc],
            updates=self.updates,
        )


    def reset(self):
        """
        Reset the state of the defense
        :return:
        """

        self.cost = self.init_cost
        K.set_value(self.cost_tensor, self.init_cost)
        K.set_value(self.opt.iterations, 0)
        for weight in self.opt.weights:
            K.set_value(weight, np.zeros(K.int_shape(weight)))

    def generate_backdoor(
        self, x_val: np.ndarray, y_val: np.ndarray, y_target: np.ndarray
    ):
        """
        Generates a possible backdoor for the model. Returns the pattern and the mask
        :return: A tuple of the pattern and mask for the model.
        """
        import keras.backend as K
        from keras_preprocessing.image import ImageDataGenerator

        self.reset()
        datagen = ImageDataGenerator()
        gen = datagen.flow(x_val, y_val, batch_size=self.batch_size)
        mask_best = None
        pattern_best = None
        reg_best = float("inf")
        cost_set_counter = 0
        cost_up_counter = 0
        cost_down_counter = 0
        cost_up_flag = False
        cost_down_flag = False
        early_stop_counter = 0
        early_stop_reg_best = reg_best
        mini_batch_size = len(x_val) // self.batch_size
        for _ in tqdm(range(self.steps), desc="Generating backdoor for class {}".format(np.argmax(y_target))):
            loss_reg_list = []
            loss_acc_list = []

            for _ in range(mini_batch_size):
                x_batch, _ = gen.next()
                y_batch = to_categorical([y_target] * x_batch.shape[0], self.num_classes) 
                batch_loss_ce, batch_loss_reg, batch_loss, batch_loss_acc = self.train([x_batch, y_batch])

                loss_reg_list.extend(list(batch_loss_reg.flatten()))
                loss_acc_list.extend(list(batch_loss_acc.flatten()))

            avg_loss_reg = np.mean(loss_reg_list)
            avg_loss_acc = np.mean(loss_acc_list)

            # save best mask/pattern so far
            if avg_loss_acc >= self.attack_success_threshold and avg_loss_reg < reg_best:
                mask_best = K.eval(self.mask_tensor)
                pattern_best = K.eval(self.pattern_tensor)
                reg_best = avg_loss_reg

            # check early stop
            if self.early_stop:
                if reg_best < float("inf"):
                    if reg_best >= self.early_stop_threshold * early_stop_reg_best:
                        early_stop_counter += 1
                    else:
                        early_stop_counter = 0
                early_stop_reg_best = min(reg_best, early_stop_reg_best)

                if cost_down_flag and cost_up_flag and early_stop_counter >= self.early_stop_patience:
                    logger.info("Early stop")
                    break

            # cost modification
            if avg_loss_acc >= self.attack_success_threshold:
                cost_set_counter += 1
                if cost_set_counter >= self.patience:
                    self.cost = self.init_cost
                    K.set_value(self.cost_tensor, self.cost)
                    cost_up_counter = 0
                    cost_down_counter = 0
                    cost_up_flag = False
                    cost_down_flag = False
            else:
                cost_set_counter = 0

            if avg_loss_acc >= self.attack_success_threshold:
                cost_up_counter += 1
                cost_down_counter = 0
            else:
                cost_up_counter = 0
                cost_down_counter += 1

            if cost_up_counter >= self.patience:
                cost_up_counter = 0
                self.cost *= self.cost_multiplier_up
                K.set_value(self.cost_tensor, self.cost)
                cost_up_flag = True
            elif cost_down_counter >= self.patience:
                cost_down_counter = 0
                self.cost /= self.cost_multiplier_down
                K.set_value(self.cost_tensor, self.cost)
                cost_down_flag = True

        if mask_best is None:
            mask_best = K.eval(self.mask_tensor)
            pattern_best = K.eval(self.pattern_tensor)
        print("attact success:{}, loss:{}, cost:{}".format(avg_loss_acc, avg_loss_reg, self.cost))
        return mask_best, pattern_best

# %%
h = NeuralCleanse(model)

# %%
mask, pattern = h.generate_backdoor(x_data, y_data,y_target=0)
# Out:
# Generating backdoor for class 0:   7%|▋         | 10/150 [04:32<1:03:45, 27.33s/it]

# %%
def image_process(array):
    if len(array.shape) > 3:
        array = np.squeeze(array, axis=0)
    clip_array = np.clip(array, 0., 255.)
    return clip_array

# %%
new_mask = image_process(mask)
plt.imshow(new_mask)

# %%
new_pattern = image_process(pattern)
plt.imshow(new_pattern)

# %%
mask_list = np.array([])
pattern_list = np.array([])
for i in range(10):
    mask, pattern = h.generate_backdoor(x_data, y_data,y_target=i)
    mask_list = np.append(mask_list, mask)
    pattern_list = np.append(pattern_list, pattern)
    # try:
    image_process(mask)
    image_process(pattern)
model_name, _ = MODEL_FILE.split('.')
np.save('mask_{}_1to10.npy'.format(model_name), mask_list)
np.save('pattern_{}_1to10.npy'.format(model_name), pattern_list)
# Out:
# Generating backdoor for class 0:   0%|          | 0/100 [00:00<?, ?it/s]
# Generating backdoor for class 0:   1%|          | 1/100 [00:25<42:49, 25.96s/it]
# Generating backdoor for class 0:   2%|▏         | 2/100 [00:51<42:22, 25.94s/it]
# Generating backdoor for class 0:   3%|▎         | 3/100 [01:17<41:56, 25.94s/it]
# Generating backdoor for class 0:   4%|▍         | 4/100 [01:43<41:29, 25.93s/it]
# Generating backdoor for class 0:   5%|▌         | 5/100 [02:09<41:01, 25.91s/it]
# Generating backdoor for class 0:   6%|▌         | 6/100 [02:35<40:38, 25.94s/it]
# Generating backdoor for class 0:   7%|▋         | 7/100 [03:01<40:11, 25.93s/it]
# Generating backdoor for class 0:   8%|▊         | 8/100 [03:27<39:39, 25.87s/it]
# Generating backdoor for class 0:   9%|▉         | 9/100 [03:52<39:06, 25.79s/it]
# Generating backdoor for class 0:  10%|█         | 10/100 [04:18<38:35, 25.73s/it]
# Generating backdoor for class 0:  11%|█         | 11/100 [04:44<38:06, 25.69s/it]
# Generating backdoor for class 0:  12%|█▏        | 12/100 [05:10<37:50, 25.80s/it]
# Generating backdoor for class 0:  13%|█▎        | 13/100 [05:35<37:21, 25.76s/it]
# Generating backdoor for class 0:  14%|█▍        | 14/100 [06:01<37:00, 25.82s/it]
# Generating backdoor for class 0:  15%|█▌        | 15/100 [06:27<36:33, 25.81s/it]
# Generating backdoor for class 0:  16%|█▌        | 16/100 [06:53<36:04, 25.77s/it]
# Generating backdoor for class 0:  17%|█▋        | 17/100 [07:18<35:34, 25.72s/it]
# Generating backdoor for class 0:  18%|█▊        | 18/100 [07:44<35:01, 25.63s/it]
# Generating backdoor for class 0:  19%|█▉        | 19/100 [08:09<34:36, 25.63s/it]
# Generating backdoor for class 0:  20%|██        | 20/100 [08:35<34:03, 25.54s/it]
# Generating backdoor for class 0:  21%|██        | 21/100 [09:00<33:29, 25.44s/it]
# Generating backdoor for class 0:  22%|██▏       | 22/100 [09:28<34:08, 26.26s/it]
# Generating backdoor for class 0:  23%|██▎       | 23/100 [09:53<33:17, 25.94s/it]
# Generating backdoor for class 0:  24%|██▍       | 24/100 [10:19<32:44, 25.85s/it]
# Generating backdoor for class 0:  25%|██▌       | 25/100 [10:44<32:12, 25.77s/it]
# Generating backdoor for class 0:  26%|██▌       | 26/100 [11:10<31:44, 25.73s/it]
# Generating backdoor for class 0:  27%|██▋       | 27/100 [11:35<31:02, 25.52s/it]
# Generating backdoor for class 0:  28%|██▊       | 28/100 [12:00<30:27, 25.38s/it]
# Generating backdoor for class 0:  29%|██▉       | 29/100 [12:25<29:57, 25.32s/it]
# Generating backdoor for class 0:  30%|███       | 30/100 [12:50<29:26, 25.23s/it]
# Generating backdoor for class 0:  31%|███       | 31/100 [13:16<29:01, 25.24s/it]
# Generating backdoor for class 0:  32%|███▏      | 32/100 [13:41<28:33, 25.20s/it]
# Generating backdoor for class 0:  33%|███▎      | 33/100 [14:06<28:02, 25.11s/it]
# Generating backdoor for class 0:  34%|███▍      | 34/100 [14:31<27:33, 25.05s/it]
# Generating backdoor for class 0:  35%|███▌      | 35/100 [14:55<27:03, 24.98s/it]
# Generating backdoor for class 0:  36%|███▌      | 36/100 [15:21<26:43, 25.05s/it]
# Generating backdoor for class 0:  37%|███▋      | 37/100 [15:45<26:14, 24.99s/it]
# Generating backdoor for class 0:  38%|███▊      | 38/100 [16:10<25:48, 24.98s/it]
# Generating backdoor for class 0:  39%|███▉      | 39/100 [16:35<25:24, 24.99s/it]
# Generating backdoor for class 0:  40%|████      | 40/100 [17:01<25:04, 25.07s/it]
# Generating backdoor for class 0:  41%|████      | 41/100 [17:26<24:43, 25.15s/it]
# Generating backdoor for class 0:  42%|████▏     | 42/100 [17:51<24:15, 25.09s/it]
# Generating backdoor for class 0:  43%|████▎     | 43/100 [18:16<23:49, 25.08s/it]
# Generating backdoor for class 0:  44%|████▍     | 44/100 [18:41<23:23, 25.06s/it]
# Generating backdoor for class 0:  45%|████▌     | 45/100 [19:06<22:58, 25.05s/it]
# Generating backdoor for class 0:  46%|████▌     | 46/100 [19:34<23:21, 25.95s/it]
# Generating backdoor for class 0:  47%|████▋     | 47/100 [19:59<22:42, 25.70s/it]
# Generating backdoor for class 0:  48%|████▊     | 48/100 [20:25<22:10, 25.59s/it]
# Generating backdoor for class 0:  49%|████▉     | 49/100 [20:50<21:47, 25.64s/it]
# Generating backdoor for class 0:  50%|█████     | 50/100 [21:16<21:22, 25.64s/it]
# Generating backdoor for class 0:  51%|█████     | 51/100 [21:42<20:57, 25.66s/it]
# Generating backdoor for class 0:  52%|█████▏    | 52/100 [22:07<20:31, 25.66s/it]
# Generating backdoor for class 0:  53%|█████▎    | 53/100 [22:33<20:05, 25.66s/it]
# Generating backdoor for class 0:  54%|█████▍    | 54/100 [22:59<19:40, 25.67s/it]
# Generating backdoor for class 0:  55%|█████▌    | 55/100 [23:25<19:19, 25.76s/it]
# Generating backdoor for class 0:  56%|█████▌    | 56/100 [23:50<18:52, 25.73s/it]
# Generating backdoor for class 0:  57%|█████▋    | 57/100 [24:16<18:25, 25.70s/it]
# Generating backdoor for class 0:  58%|█████▊    | 58/100 [24:42<17:57, 25.67s/it]
# Generating backdoor for class 0:  59%|█████▉    | 59/100 [25:07<17:31, 25.65s/it]
# Generating backdoor for class 0:  60%|██████    | 60/100 [25:33<17:07, 25.70s/it]
# Generating backdoor for class 0:  61%|██████    | 61/100 [25:59<16:43, 25.72s/it]
# Generating backdoor for class 0:  62%|██████▏   | 62/100 [26:24<16:14, 25.66s/it]
# Generating backdoor for class 0:  63%|██████▎   | 63/100 [26:50<15:50, 25.68s/it]
# Generating backdoor for class 0:  64%|██████▍   | 64/100 [27:16<15:26, 25.73s/it]
# Generating backdoor for class 0:  65%|██████▌   | 65/100 [27:41<14:57, 25.63s/it]
# Generating backdoor for class 0:  66%|██████▌   | 66/100 [28:06<14:25, 25.45s/it]
# Generating backdoor for class 0:  67%|██████▋   | 67/100 [28:31<13:56, 25.35s/it]
# Generating backdoor for class 0:  68%|██████▊   | 68/100 [28:56<13:27, 25.23s/it]
# Generating backdoor for class 0:  69%|██████▉   | 69/100 [29:22<13:05, 25.34s/it]
# Generating backdoor for class 0:  70%|███████   | 70/100 [29:50<13:08, 26.28s/it]
# Generating backdoor for class 0:  71%|███████   | 71/100 [30:16<12:34, 26.00s/it]
# Generating backdoor for class 0:  72%|███████▏  | 72/100 [30:41<12:00, 25.75s/it]
# Generating backdoor for class 0:  73%|███████▎  | 73/100 [31:06<11:32, 25.66s/it]
# Generating backdoor for class 0:  74%|███████▍  | 74/100 [31:32<11:04, 25.57s/it]
# Generating backdoor for class 0:  75%|███████▌  | 75/100 [31:58<10:41, 25.68s/it]
# Generating backdoor for class 0:  76%|███████▌  | 76/100 [32:23<10:13, 25.58s/it]
# Generating backdoor for class 0:  77%|███████▋  | 77/100 [32:48<09:47, 25.53s/it]
# Generating backdoor for class 0:  78%|███████▊  | 78/100 [33:14<09:20, 25.48s/it]
# Generating backdoor for class 0:  79%|███████▉  | 79/100 [33:39<08:52, 25.36s/it]
# Generating backdoor for class 0:  80%|████████  | 80/100 [34:04<08:28, 25.42s/it]
# Generating backdoor for class 0:  81%|████████  | 81/100 [34:30<08:03, 25.46s/it]
# Generating backdoor for class 0:  82%|████████▏ | 82/100 [34:56<07:40, 25.56s/it]
# Generating backdoor for class 0:  83%|████████▎ | 83/100 [35:22<07:15, 25.63s/it]
# Generating backdoor for class 0:  84%|████████▍ | 84/100 [35:47<06:51, 25.73s/it]
# Generating backdoor for class 0:  85%|████████▌ | 85/100 [36:13<06:26, 25.78s/it]
# Generating backdoor for class 0:  86%|████████▌ | 86/100 [36:39<06:00, 25.78s/it]
# Generating backdoor for class 0:  87%|████████▋ | 87/100 [37:05<05:36, 25.86s/it]
# Generating backdoor for class 0:  88%|████████▊ | 88/100 [37:31<05:10, 25.84s/it]
# Generating backdoor for class 0:  89%|████████▉ | 89/100 [37:57<04:43, 25.80s/it]
# Generating backdoor for class 0:  90%|█████████ | 90/100 [38:23<04:18, 25.86s/it]
# Generating backdoor for class 0:  91%|█████████ | 91/100 [38:48<03:52, 25.83s/it]
# Generating backdoor for class 0:  92%|█████████▏| 92/100 [39:14<03:25, 25.74s/it]
# Generating backdoor for class 0:  93%|█████████▎| 93/100 [39:42<03:04, 26.39s/it]
# Generating backdoor for class 0:  94%|█████████▍| 94/100 [40:08<02:37, 26.22s/it]
# Generating backdoor for class 0:  95%|█████████▌| 95/100 [40:34<02:10, 26.10s/it]
# Generating backdoor for class 0:  96%|█████████▌| 96/100 [40:59<01:44, 26.04s/it]
# Generating backdoor for class 0:  97%|█████████▋| 97/100 [41:25<01:17, 25.98s/it]
# Generating backdoor for class 0:  98%|█████████▊| 98/100 [41:51<00:51, 25.88s/it]
# Generating backdoor for class 0:  99%|█████████▉| 99/100 [42:17<00:25, 25.90s/it]
# Generating backdoor for class 0: 100%|██████████| 100/100 [42:42<00:00, 25.63s/it]
#
# Generating backdoor for class 0:   0%|          | 0/100 [00:00<?, ?it/s]
# Generating backdoor for class 0:   1%|          | 1/100 [00:25<41:57, 25.43s/it]
# Generating backdoor for class 0:   2%|▏         | 2/100 [00:50<41:21, 25.33s/it]
# Generating backdoor for class 0:   3%|▎         | 3/100 [01:15<40:47, 25.24s/it]
# Generating backdoor for class 0:   4%|▍         | 4/100 [01:40<40:15, 25.17s/it]
# Generating backdoor for class 0:   5%|▌         | 5/100 [02:05<39:41, 25.07s/it]
# Generating backdoor for class 0:   6%|▌         | 6/100 [02:30<39:31, 25.23s/it]
# Generating backdoor for class 0:   7%|▋         | 7/100 [02:56<39:21, 25.40s/it]
# Generating backdoor for class 0:   8%|▊         | 8/100 [03:22<39:13, 25.58s/it]
# Generating backdoor for class 0:   9%|▉         | 9/100 [03:48<38:56, 25.67s/it]
# Generating backdoor for class 0:  10%|█         | 10/100 [04:14<38:31, 25.69s/it]
# Generating backdoor for class 0:  11%|█         | 11/100 [04:40<38:20, 25.85s/it]
# Generating backdoor for class 0:  12%|█▏        | 12/100 [05:06<38:03, 25.95s/it]
# Generating backdoor for class 0:  13%|█▎        | 13/100 [05:32<37:43, 26.02s/it]
# Generating backdoor for class 0:  14%|█▍        | 14/100 [05:59<37:18, 26.03s/it]
# Generating backdoor for class 0:  15%|█▌        | 15/100 [06:25<36:56, 26.08s/it]
# Generating backdoor for class 0:  16%|█▌        | 16/100 [06:51<36:33, 26.12s/it]
# Generating backdoor for class 0:  17%|█▋        | 17/100 [07:20<37:21, 27.01s/it]
# Generating backdoor for class 0:  18%|█▊        | 18/100 [07:46<36:36, 26.78s/it]
# Generating backdoor for class 0:  19%|█▉        | 19/100 [08:13<35:56, 26.63s/it]
# Generating backdoor for class 0:  20%|██        | 20/100 [08:39<35:27, 26.59s/it]
# Generating backdoor for class 0:  21%|██        | 21/100 [09:05<34:54, 26.51s/it]
# Generating backdoor for class 0:  22%|██▏       | 22/100 [09:32<34:21, 26.43s/it]
# Generating backdoor for class 0:  23%|██▎       | 23/100 [09:58<33:52, 26.40s/it]
# Generating backdoor for class 0:  24%|██▍       | 24/100 [10:24<33:19, 26.31s/it]
# Generating backdoor for class 0:  25%|██▌       | 25/100 [10:50<32:46, 26.22s/it]
# Generating backdoor for class 0:  26%|██▌       | 26/100 [11:16<32:20, 26.23s/it]
# Generating backdoor for class 0:  27%|██▋       | 27/100 [11:43<31:56, 26.26s/it]
# Generating backdoor for class 0:  28%|██▊       | 28/100 [12:09<31:31, 26.27s/it]
# Generating backdoor for class 0:  29%|██▉       | 29/100 [12:35<31:08, 26.32s/it]
# Generating backdoor for class 0:  30%|███       | 30/100 [13:02<30:40, 26.30s/it]
# Generating backdoor for class 0:  31%|███       | 31/100 [13:28<30:15, 26.31s/it]
# Generating backdoor for class 0:  32%|███▏      | 32/100 [13:54<29:47, 26.28s/it]
# Generating backdoor for class 0:  33%|███▎      | 33/100 [14:20<29:19, 26.26s/it]
# Generating backdoor for class 0:  34%|███▍      | 34/100 [14:47<28:53, 26.27s/it]
# Generating backdoor for class 0:  35%|███▌      | 35/100 [15:13<28:34, 26.37s/it]
# Generating backdoor for class 0:  36%|███▌      | 36/100 [15:41<28:29, 26.71s/it]
# Generating backdoor for class 0:  37%|███▋      | 37/100 [16:07<27:54, 26.58s/it]
# Generating backdoor for class 0:  38%|███▊      | 38/100 [16:33<27:21, 26.48s/it]
# Generating backdoor for class 0:  39%|███▉      | 39/100 [16:59<26:49, 26.39s/it]
# Generating backdoor for class 0:  40%|████      | 40/100 [17:29<27:12, 27.20s/it]
# Generating backdoor for class 0:  41%|████      | 41/100 [17:55<26:26, 26.88s/it]
# Generating backdoor for class 0:  42%|████▏     | 42/100 [18:22<26:01, 26.93s/it]
# Generating backdoor for class 0:  43%|████▎     | 43/100 [18:48<25:24, 26.74s/it]
# Generating backdoor for class 0:  44%|████▍     | 44/100 [19:14<24:49, 26.59s/it]
# Generating backdoor for class 0:  45%|████▌     | 45/100 [19:41<24:16, 26.48s/it]
# Generating backdoor for class 0:  46%|████▌     | 46/100 [20:07<23:47, 26.43s/it]
# Generating backdoor for class 0:  47%|████▋     | 47/100 [20:33<23:18, 26.39s/it]
# Generating backdoor for class 0:  48%|████▊     | 48/100 [20:59<22:49, 26.34s/it]
# Generating backdoor for class 0:  49%|████▉     | 49/100 [21:26<22:21, 26.29s/it]
# Generating backdoor for class 0:  50%|█████     | 50/100 [21:52<21:53, 26.28s/it]
# Generating backdoor for class 0:  51%|█████     | 51/100 [22:18<21:26, 26.26s/it]
# Generating backdoor for class 0:  52%|█████▏    | 52/100 [22:44<20:58, 26.22s/it]
# Generating backdoor for class 0:  53%|█████▎    | 53/100 [23:11<20:37, 26.32s/it]
# Generating backdoor for class 0:  54%|█████▍    | 54/100 [23:37<20:14, 26.40s/it]
# Generating backdoor for class 0:  55%|█████▌    | 55/100 [24:03<19:44, 26.33s/it]
# Generating backdoor for class 0:  56%|█████▌    | 56/100 [24:30<19:17, 26.30s/it]
# Generating backdoor for class 0:  57%|█████▋    | 57/100 [24:56<18:48, 26.26s/it]
# Generating backdoor for class 0:  58%|█████▊    | 58/100 [25:22<18:24, 26.29s/it]
# Generating backdoor for class 0:  59%|█████▉    | 59/100 [25:48<17:57, 26.28s/it]
# Generating backdoor for class 0:  60%|██████    | 60/100 [26:15<17:29, 26.23s/it]
# Generating backdoor for class 0:  61%|██████    | 61/100 [26:41<17:01, 26.20s/it]
# Generating backdoor for class 0:  62%|██████▏   | 62/100 [27:07<16:34, 26.17s/it]
# Generating backdoor for class 0:  63%|██████▎   | 63/100 [27:36<16:39, 27.01s/it]
# Generating backdoor for class 0:  64%|██████▍   | 64/100 [28:02<16:01, 26.72s/it]
# Generating backdoor for class 0:  65%|██████▌   | 65/100 [28:28<15:27, 26.50s/it]
# Generating backdoor for class 0:  66%|██████▌   | 66/100 [28:54<14:55, 26.34s/it]
# Generating backdoor for class 0:  67%|██████▋   | 67/100 [29:20<14:24, 26.20s/it]
# Generating backdoor for class 0:  68%|██████▊   | 68/100 [29:45<13:52, 26.03s/it]
# Generating backdoor for class 0:  69%|██████▉   | 69/100 [30:11<13:25, 25.99s/it]
# Generating backdoor for class 0:  70%|███████   | 70/100 [30:37<13:00, 26.02s/it]
# Generating backdoor for class 0:  71%|███████   | 71/100 [31:03<12:34, 26.00s/it]
# Generating backdoor for class 0:  72%|███████▏  | 72/100 [31:29<12:09, 26.04s/it]
# Generating backdoor for class 0:  73%|███████▎  | 73/100 [31:55<11:43, 26.05s/it]
# Generating backdoor for class 0:  74%|███████▍  | 74/100 [32:21<11:17, 26.05s/it]
# Generating backdoor for class 0:  75%|███████▌  | 75/100 [32:48<10:52, 26.10s/it]
# Generating backdoor for class 0:  76%|███████▌  | 76/100 [33:14<10:30, 26.26s/it]
# Generating backdoor for class 0:  77%|███████▋  | 77/100 [33:40<10:03, 26.24s/it]
# Generating backdoor for class 0:  78%|███████▊  | 78/100 [34:07<09:36, 26.23s/it]
# Generating backdoor for class 0:  79%|███████▉  | 79/100 [34:33<09:09, 26.16s/it]
# Generating backdoor for class 0:  80%|████████  | 80/100 [34:59<08:42, 26.12s/it]
# Generating backdoor for class 0:  81%|████████  | 81/100 [35:25<08:14, 26.03s/it]
# Generating backdoor for class 0:  82%|████████▏ | 82/100 [35:51<07:49, 26.06s/it]
# Generating backdoor for class 0:  83%|████████▎ | 83/100 [36:17<07:22, 26.02s/it]
# Generating backdoor for class 0:  84%|████████▍ | 84/100 [36:43<06:56, 26.03s/it]
# Generating backdoor for class 0:  85%|████████▌ | 85/100 [37:09<06:30, 26.02s/it]
# Generating backdoor for class 0:  86%|████████▌ | 86/100 [37:36<06:10, 26.47s/it]
# Generating backdoor for class 0:  87%|████████▋ | 87/100 [38:04<05:47, 26.74s/it]
# Generating backdoor for class 0:  88%|████████▊ | 88/100 [38:29<05:17, 26.50s/it]
# Generating backdoor for class 0:  89%|████████▉ | 89/100 [38:56<04:49, 26.36s/it]
# Generating backdoor for class 0:  90%|█████████ | 90/100 [39:22<04:22, 26.26s/it]
# Generating backdoor for class 0:  91%|█████████ | 91/100 [39:47<03:55, 26.15s/it]
# Generating backdoor for class 0:  92%|█████████▏| 92/100 [40:13<03:28, 26.05s/it]
# Generating backdoor for class 0:  93%|█████████▎| 93/100 [40:39<03:02, 26.04s/it]
# Generating backdoor for class 0:  94%|█████████▍| 94/100 [41:05<02:36, 26.08s/it]
# Generating backdoor for class 0:  95%|█████████▌| 95/100 [41:31<02:09, 25.99s/it]
# Generating backdoor for class 0:  96%|█████████▌| 96/100 [41:57<01:43, 25.79s/it]
# Generating backdoor for class 0:  97%|█████████▋| 97/100 [42:22<01:16, 25.59s/it]
# Generating backdoor for class 0:  98%|█████████▊| 98/100 [42:47<00:50, 25.48s/it]
# Generating backdoor for class 0:  99%|█████████▉| 99/100 [43:12<00:25, 25.43s/it]
# Generating backdoor for class 0: 100%|██████████| 100/100 [43:37<00:00, 26.18s/it]
#
# Generating backdoor for class 0:   0%|          | 0/100 [00:00<?, ?it/s]
# Generating backdoor for class 0:   1%|          | 1/100 [00:25<41:28, 25.14s/it]
# Generating backdoor for class 0:   2%|▏         | 2/100 [00:50<41:13, 25.24s/it]
# Generating backdoor for class 0:   3%|▎         | 3/100 [01:16<41:01, 25.38s/it]
# Generating backdoor for class 0:   4%|▍         | 4/100 [01:41<40:43, 25.45s/it]
# Generating backdoor for class 0:   5%|▌         | 5/100 [02:07<40:24, 25.53s/it]
# Generating backdoor for class 0:   6%|▌         | 6/100 [02:33<40:09, 25.63s/it]
# Generating backdoor for class 0:   7%|▋         | 7/100 [02:59<39:53, 25.74s/it]
# Generating backdoor for class 0:   8%|▊         | 8/100 [03:25<39:36, 25.83s/it]
# Generating backdoor for class 0:   9%|▉         | 9/100 [03:51<39:18, 25.92s/it]
# Generating backdoor for class 0:  10%|█         | 10/100 [04:20<40:16, 26.85s/it]
# Generating backdoor for class 0:  11%|█         | 11/100 [04:46<39:30, 26.63s/it]
# Generating backdoor for class 0:  12%|█▏        | 12/100 [05:13<38:52, 26.51s/it]
# Generating backdoor for class 0:  13%|█▎        | 13/100 [05:39<38:19, 26.43s/it]
# Generating backdoor for class 0:  14%|█▍        | 14/100 [06:05<37:48, 26.38s/it]
# Generating backdoor for class 0:  15%|█▌        | 15/100 [06:31<37:19, 26.34s/it]
# Generating backdoor for class 0:  16%|█▌        | 16/100 [06:58<36:49, 26.31s/it]
# Generating backdoor for class 0:  17%|█▋        | 17/100 [07:24<36:19, 26.26s/it]
# Generating backdoor for class 0:  18%|█▊        | 18/100 [07:50<35:54, 26.28s/it]
# Generating backdoor for class 0:  19%|█▉        | 19/100 [08:16<35:26, 26.25s/it]
# Generating backdoor for class 0:  20%|██        | 20/100 [08:42<34:57, 26.22s/it]
# Generating backdoor for class 0:  21%|██        | 21/100 [09:09<34:32, 26.24s/it]
# Generating backdoor for class 0:  22%|██▏       | 22/100 [09:35<34:05, 26.23s/it]
# Generating backdoor for class 0:  23%|██▎       | 23/100 [10:01<33:39, 26.23s/it]
# Generating backdoor for class 0:  24%|██▍       | 24/100 [10:27<33:11, 26.20s/it]
# Generating backdoor for class 0:  25%|██▌       | 25/100 [10:53<32:46, 26.21s/it]
# Generating backdoor for class 0:  26%|██▌       | 26/100 [11:20<32:18, 26.19s/it]
# Generating backdoor for class 0:  27%|██▋       | 27/100 [11:46<31:50, 26.17s/it]
# Generating backdoor for class 0:  28%|██▊       | 28/100 [12:12<31:23, 26.16s/it]
# Generating backdoor for class 0:  29%|██▉       | 29/100 [12:38<30:56, 26.15s/it]
# Generating backdoor for class 0:  30%|███       | 30/100 [13:04<30:36, 26.24s/it]
# Generating backdoor for class 0:  31%|███       | 31/100 [13:31<30:10, 26.23s/it]
# Generating backdoor for class 0:  32%|███▏      | 32/100 [13:57<29:41, 26.20s/it]
# Generating backdoor for class 0:  33%|███▎      | 33/100 [14:26<30:12, 27.06s/it]
# Generating backdoor for class 0:  34%|███▍      | 34/100 [14:52<29:30, 26.82s/it]
# Generating backdoor for class 0:  35%|███▌      | 35/100 [15:18<28:51, 26.64s/it]
# Generating backdoor for class 0:  36%|███▌      | 36/100 [15:44<28:15, 26.50s/it]
# Generating backdoor for class 0:  37%|███▋      | 37/100 [16:11<27:41, 26.37s/it]
# Generating backdoor for class 0:  38%|███▊      | 38/100 [16:37<27:09, 26.29s/it]
# Generating backdoor for class 0:  39%|███▉      | 39/100 [17:03<26:39, 26.22s/it]
# Generating backdoor for class 0:  40%|████      | 40/100 [17:29<26:11, 26.19s/it]
# Generating backdoor for class 0:  41%|████      | 41/100 [17:55<25:44, 26.18s/it]
# Generating backdoor for class 0:  42%|████▏     | 42/100 [18:21<25:19, 26.19s/it]
# Generating backdoor for class 0:  43%|████▎     | 43/100 [18:47<24:51, 26.17s/it]
# Generating backdoor for class 0:  44%|████▍     | 44/100 [19:13<24:23, 26.14s/it]
# Generating backdoor for class 0:  45%|████▌     | 45/100 [19:39<23:57, 26.13s/it]
# Generating backdoor for class 0:  46%|████▌     | 46/100 [20:06<23:31, 26.13s/it]
# Generating backdoor for class 0:  47%|████▋     | 47/100 [20:32<23:05, 26.14s/it]
# Generating backdoor for class 0:  48%|████▊     | 48/100 [20:58<22:40, 26.17s/it]
# Generating backdoor for class 0:  49%|████▉     | 49/100 [21:24<22:13, 26.14s/it]
# Generating backdoor for class 0:  50%|█████     | 50/100 [21:50<21:45, 26.11s/it]
# Generating backdoor for class 0:  51%|█████     | 51/100 [22:16<21:17, 26.06s/it]
# Generating backdoor for class 0:  52%|█████▏    | 52/100 [22:42<20:49, 26.02s/it]
# Generating backdoor for class 0:  53%|█████▎    | 53/100 [23:08<20:25, 26.07s/it]
# Generating backdoor for class 0:  54%|█████▍    | 54/100 [23:34<19:59, 26.09s/it]
# Generating backdoor for class 0:  55%|█████▌    | 55/100 [24:01<19:37, 26.16s/it]
# Generating backdoor for class 0:  56%|█████▌    | 56/100 [24:29<19:41, 26.86s/it]
# Generating backdoor for class 0:  57%|█████▋    | 57/100 [24:57<19:24, 27.09s/it]
# Generating backdoor for class 0:  58%|█████▊    | 58/100 [25:23<18:48, 26.88s/it]
# Generating backdoor for class 0:  59%|█████▉    | 59/100 [25:49<18:12, 26.64s/it]
# Generating backdoor for class 0:  60%|██████    | 60/100 [26:16<17:46, 26.66s/it]
# Generating backdoor for class 0:  61%|██████    | 61/100 [26:42<17:14, 26.53s/it]
# Generating backdoor for class 0:  62%|██████▏   | 62/100 [27:08<16:45, 26.46s/it]
# Generating backdoor for class 0:  63%|██████▎   | 63/100 [27:35<16:15, 26.36s/it]
# Generating backdoor for class 0:  64%|██████▍   | 64/100 [28:00<15:42, 26.17s/it]
# Generating backdoor for class 0:  65%|██████▌   | 65/100 [28:26<15:14, 26.12s/it]
# Generating backdoor for class 0:  66%|██████▌   | 66/100 [28:52<14:44, 26.02s/it]
# Generating backdoor for class 0:  67%|██████▋   | 67/100 [29:18<14:17, 25.98s/it]
# Generating backdoor for class 0:  68%|██████▊   | 68/100 [29:44<13:51, 26.00s/it]
# Generating backdoor for class 0:  69%|██████▉   | 69/100 [30:10<13:25, 25.97s/it]
# Generating backdoor for class 0:  70%|███████   | 70/100 [30:36<13:00, 26.01s/it]
# Generating backdoor for class 0:  71%|███████   | 71/100 [31:02<12:33, 25.98s/it]
# Generating backdoor for class 0:  72%|███████▏  | 72/100 [31:28<12:06, 25.95s/it]
# Generating backdoor for class 0:  73%|███████▎  | 73/100 [31:54<11:40, 25.93s/it]
# Generating backdoor for class 0:  74%|███████▍  | 74/100 [32:19<11:11, 25.84s/it]
# Generating backdoor for class 0:  75%|███████▌  | 75/100 [32:45<10:43, 25.75s/it]
# Generating backdoor for class 0:  76%|███████▌  | 76/100 [33:11<10:17, 25.73s/it]
# Generating backdoor for class 0:  77%|███████▋  | 77/100 [33:36<09:52, 25.77s/it]
# Generating backdoor for class 0:  78%|███████▊  | 78/100 [34:02<09:25, 25.73s/it]
# Generating backdoor for class 0:  79%|███████▉  | 79/100 [34:27<08:56, 25.53s/it]
# Generating backdoor for class 0:  80%|████████  | 80/100 [34:55<08:46, 26.33s/it]
# Generating backdoor for class 0:  81%|████████  | 81/100 [35:21<08:14, 26.03s/it]
# Generating backdoor for class 0:  82%|████████▏ | 82/100 [35:46<07:46, 25.92s/it]
# Generating backdoor for class 0:  83%|████████▎ | 83/100 [36:12<07:20, 25.94s/it]
# Generating backdoor for class 0:  84%|████████▍ | 84/100 [36:38<06:54, 25.91s/it]
# Generating backdoor for class 0:  85%|████████▌ | 85/100 [37:04<06:28, 25.90s/it]
# Generating backdoor for class 0:  86%|████████▌ | 86/100 [37:30<06:01, 25.85s/it]
# Generating backdoor for class 0:  87%|████████▋ | 87/100 [37:55<05:34, 25.76s/it]
# Generating backdoor for class 0:  88%|████████▊ | 88/100 [38:21<05:09, 25.76s/it]
# Generating backdoor for class 0:  89%|████████▉ | 89/100 [38:47<04:43, 25.79s/it]
# Generating backdoor for class 0:  90%|█████████ | 90/100 [39:12<04:17, 25.74s/it]
# Generating backdoor for class 0:  91%|█████████ | 91/100 [39:38<03:51, 25.74s/it]
# Generating backdoor for class 0:  92%|█████████▏| 92/100 [40:04<03:25, 25.68s/it]
# Generating backdoor for class 0:  93%|█████████▎| 93/100 [40:29<02:59, 25.66s/it]
# Generating backdoor for class 0:  94%|█████████▍| 94/100 [40:55<02:33, 25.58s/it]
# Generating backdoor for class 0:  95%|█████████▌| 95/100 [41:20<02:07, 25.52s/it]
# Generating backdoor for class 0:  96%|█████████▌| 96/100 [41:45<01:41, 25.41s/it]
# Generating backdoor for class 0:  97%|█████████▋| 97/100 [42:10<01:15, 25.32s/it]
# Generating backdoor for class 0:  98%|█████████▊| 98/100 [42:36<00:50, 25.28s/it]
# Generating backdoor for class 0:  99%|█████████▉| 99/100 [43:01<00:25, 25.41s/it]
# Generating backdoor for class 0: 100%|██████████| 100/100 [43:27<00:00, 26.07s/it]
#
# Generating backdoor for class 0:   0%|          | 0/100 [00:00<?, ?it/s]
# Generating backdoor for class 0:   1%|          | 1/100 [00:25<42:05, 25.51s/it]
# Generating backdoor for class 0:   2%|▏         | 2/100 [00:51<41:48, 25.59s/it]
# Generating backdoor for class 0:   3%|▎         | 3/100 [01:16<41:24, 25.61s/it]
# Generating backdoor for class 0:   4%|▍         | 4/100 [01:45<42:31, 26.58s/it]
# Generating backdoor for class 0:   5%|▌         | 5/100 [02:11<41:44, 26.36s/it]
# Generating backdoor for class 0:   6%|▌         | 6/100 [02:37<40:54, 26.11s/it]
# Generating backdoor for class 0:   7%|▋         | 7/100 [03:02<40:09, 25.91s/it]
# Generating backdoor for class 0:   8%|▊         | 8/100 [03:28<39:34, 25.81s/it]
# Generating backdoor for class 0:   9%|▉         | 9/100 [03:53<39:05, 25.78s/it]
# Generating backdoor for class 0:  10%|█         | 10/100 [04:19<38:42, 25.81s/it]
# Generating backdoor for class 0:  11%|█         | 11/100 [04:45<38:19, 25.84s/it]
# Generating backdoor for class 0:  12%|█▏        | 12/100 [05:11<37:51, 25.81s/it]
# Generating backdoor for class 0:  13%|█▎        | 13/100 [05:37<37:31, 25.88s/it]
# Generating backdoor for class 0:  14%|█▍        | 14/100 [06:03<37:03, 25.86s/it]
# Generating backdoor for class 0:  15%|█▌        | 15/100 [06:28<36:31, 25.78s/it]
# Generating backdoor for class 0:  16%|█▌        | 16/100 [06:54<35:59, 25.70s/it]
# Generating backdoor for class 0:  17%|█▋        | 17/100 [07:19<35:26, 25.62s/it]
# Generating backdoor for class 0:  18%|█▊        | 18/100 [07:45<34:56, 25.56s/it]
# Generating backdoor for class 0:  19%|█▉        | 19/100 [08:11<34:35, 25.62s/it]
# Generating backdoor for class 0:  20%|██        | 20/100 [08:36<34:14, 25.69s/it]
# Generating backdoor for class 0:  21%|██        | 21/100 [09:02<33:58, 25.80s/it]
# Generating backdoor for class 0:  22%|██▏       | 22/100 [09:29<33:40, 25.90s/it]
# Generating backdoor for class 0:  23%|██▎       | 23/100 [09:55<33:17, 25.95s/it]
# Generating backdoor for class 0:  24%|██▍       | 24/100 [10:21<32:57, 26.02s/it]
# Generating backdoor for class 0:  25%|██▌       | 25/100 [10:47<32:37, 26.09s/it]
# Generating backdoor for class 0:  26%|██▌       | 26/100 [11:13<32:14, 26.14s/it]
# Generating backdoor for class 0:  27%|██▋       | 27/100 [11:42<32:51, 27.01s/it]
# Generating backdoor for class 0:  28%|██▊       | 28/100 [12:09<32:07, 26.77s/it]
# Generating backdoor for class 0:  29%|██▉       | 29/100 [12:35<31:27, 26.58s/it]
# Generating backdoor for class 0:  30%|███       | 30/100 [13:01<30:53, 26.47s/it]
# Generating backdoor for class 0:  31%|███       | 31/100 [13:27<30:20, 26.39s/it]
# Generating backdoor for class 0:  32%|███▏      | 32/100 [13:53<29:47, 26.29s/it]
# Generating backdoor for class 0:  33%|███▎      | 33/100 [14:19<29:16, 26.21s/it]
# Generating backdoor for class 0:  34%|███▍      | 34/100 [14:45<28:46, 26.16s/it]
# Generating backdoor for class 0:  35%|███▌      | 35/100 [15:11<28:19, 26.15s/it]
# Generating backdoor for class 0:  36%|███▌      | 36/100 [15:37<27:53, 26.14s/it]
# Generating backdoor for class 0:  37%|███▋      | 37/100 [16:04<27:28, 26.16s/it]
# Generating backdoor for class 0:  38%|███▊      | 38/100 [16:30<27:02, 26.17s/it]
# Generating backdoor for class 0:  39%|███▉      | 39/100 [16:56<26:38, 26.20s/it]
# Generating backdoor for class 0:  40%|████      | 40/100 [17:22<26:12, 26.20s/it]
# Generating backdoor for class 0:  41%|████      | 41/100 [17:49<25:47, 26.22s/it]
# Generating backdoor for class 0:  42%|████▏     | 42/100 [18:15<25:22, 26.25s/it]
# Generating backdoor for class 0:  43%|████▎     | 43/100 [18:41<24:56, 26.26s/it]
# Generating backdoor for class 0:  44%|████▍     | 44/100 [19:08<24:33, 26.31s/it]
# Generating backdoor for class 0:  45%|████▌     | 45/100 [19:34<24:07, 26.32s/it]
# Generating backdoor for class 0:  46%|████▌     | 46/100 [20:00<23:38, 26.26s/it]
# Generating backdoor for class 0:  47%|████▋     | 47/100 [20:26<23:13, 26.28s/it]
# Generating backdoor for class 0:  48%|████▊     | 48/100 [20:53<22:45, 26.25s/it]
# Generating backdoor for class 0:  49%|████▉     | 49/100 [21:19<22:19, 26.27s/it]
# Generating backdoor for class 0:  50%|█████     | 50/100 [21:48<22:36, 27.14s/it]
# Generating backdoor for class 0:  51%|█████     | 51/100 [22:14<21:56, 26.87s/it]
# Generating backdoor for class 0:  52%|█████▏    | 52/100 [22:41<21:20, 26.68s/it]
# Generating backdoor for class 0:  53%|█████▎    | 53/100 [23:07<20:47, 26.55s/it]
# Generating backdoor for class 0:  54%|█████▍    | 54/100 [23:33<20:19, 26.52s/it]
# Generating backdoor for class 0:  55%|█████▌    | 55/100 [23:59<19:49, 26.43s/it]
# Generating backdoor for class 0:  56%|█████▌    | 56/100 [24:26<19:19, 26.36s/it]
# Generating backdoor for class 0:  57%|█████▋    | 57/100 [24:52<18:50, 26.28s/it]
# Generating backdoor for class 0:  58%|█████▊    | 58/100 [25:18<18:22, 26.25s/it]
# Generating backdoor for class 0:  59%|█████▉    | 59/100 [25:44<17:54, 26.21s/it]
# Generating backdoor for class 0:  60%|██████    | 60/100 [26:10<17:28, 26.22s/it]
# Generating backdoor for class 0:  61%|██████    | 61/100 [26:37<17:03, 26.24s/it]
# Generating backdoor for class 0:  62%|██████▏   | 62/100 [27:03<16:36, 26.22s/it]
# Generating backdoor for class 0:  63%|██████▎   | 63/100 [27:29<16:08, 26.18s/it]
# Generating backdoor for class 0:  64%|██████▍   | 64/100 [27:55<15:41, 26.16s/it]
# Generating backdoor for class 0:  65%|██████▌   | 65/100 [28:21<15:17, 26.23s/it]
# Generating backdoor for class 0:  66%|██████▌   | 66/100 [28:48<14:53, 26.28s/it]
# Generating backdoor for class 0:  67%|██████▋   | 67/100 [29:14<14:28, 26.33s/it]
# Generating backdoor for class 0:  68%|██████▊   | 68/100 [29:40<14:00, 26.26s/it]
# Generating backdoor for class 0:  69%|██████▉   | 69/100 [30:06<13:32, 26.20s/it]
# Generating backdoor for class 0:  70%|███████   | 70/100 [30:33<13:05, 26.20s/it]
# Generating backdoor for class 0:  71%|███████   | 71/100 [30:59<12:41, 26.27s/it]
# Generating backdoor for class 0:  72%|███████▏  | 72/100 [31:25<12:16, 26.32s/it]
# Generating backdoor for class 0:  73%|███████▎  | 73/100 [31:54<12:11, 27.09s/it]
# Generating backdoor for class 0:  74%|███████▍  | 74/100 [32:20<11:35, 26.74s/it]
# Generating backdoor for class 0:  75%|███████▌  | 75/100 [32:46<11:01, 26.47s/it]
# Generating backdoor for class 0:  76%|███████▌  | 76/100 [33:12<10:30, 26.29s/it]
# Generating backdoor for class 0:  77%|███████▋  | 77/100 [33:38<10:02, 26.18s/it]
# Generating backdoor for class 0:  78%|███████▊  | 78/100 [34:04<09:34, 26.10s/it]
# Generating backdoor for class 0:  79%|███████▉  | 79/100 [34:30<09:08, 26.10s/it]
# Generating backdoor for class 0:  80%|████████  | 80/100 [34:56<08:42, 26.13s/it]
# Generating backdoor for class 0:  81%|████████  | 81/100 [35:22<08:16, 26.13s/it]
# Generating backdoor for class 0:  82%|████████▏ | 82/100 [35:48<07:50, 26.14s/it]
# Generating backdoor for class 0:  83%|████████▎ | 83/100 [36:14<07:23, 26.09s/it]
# Generating backdoor for class 0:  84%|████████▍ | 84/100 [36:41<06:57, 26.12s/it]
# Generating backdoor for class 0:  85%|████████▌ | 85/100 [37:07<06:31, 26.10s/it]
# Generating backdoor for class 0:  86%|████████▌ | 86/100 [37:33<06:05, 26.07s/it]
# Generating backdoor for class 0:  87%|████████▋ | 87/100 [37:58<05:37, 25.97s/it]
# Generating backdoor for class 0:  88%|████████▊ | 88/100 [38:24<05:11, 25.93s/it]
# Generating backdoor for class 0:  89%|████████▉ | 89/100 [38:50<04:45, 25.96s/it]
# Generating backdoor for class 0:  90%|█████████ | 90/100 [39:16<04:19, 25.97s/it]
# Generating backdoor for class 0:  91%|█████████ | 91/100 [39:42<03:53, 25.93s/it]
# Generating backdoor for class 0:  92%|█████████▏| 92/100 [40:08<03:26, 25.85s/it]
# Generating backdoor for class 0:  93%|█████████▎| 93/100 [40:34<03:01, 25.87s/it]
# Generating backdoor for class 0:  94%|█████████▍| 94/100 [40:59<02:35, 25.84s/it]
# Generating backdoor for class 0:  95%|█████████▌| 95/100 [41:25<02:09, 25.89s/it]
# Generating backdoor for class 0:  96%|█████████▌| 96/100 [41:52<01:43, 25.99s/it]
# Generating backdoor for class 0:  97%|█████████▋| 97/100 [42:21<01:20, 26.91s/it]
# Generating backdoor for class 0:  98%|█████████▊| 98/100 [42:47<00:53, 26.61s/it]
# Generating backdoor for class 0:  99%|█████████▉| 99/100 [43:13<00:26, 26.42s/it]
# Generating backdoor for class 0: 100%|██████████| 100/100 [43:38<00:00, 26.19s/it]
#
# Generating backdoor for class 0:   0%|          | 0/100 [00:00<?, ?it/s]
# Generating backdoor for class 0:   1%|          | 1/100 [00:25<42:39, 25.85s/it]
# Generating backdoor for class 0:   2%|▏         | 2/100 [00:51<42:14, 25.86s/it]
# Generating backdoor for class 0:   3%|▎         | 3/100 [01:17<41:50, 25.88s/it]
# Generating backdoor for class 0:   4%|▍         | 4/100 [01:43<41:15, 25.78s/it]
# Generating backdoor for class 0:   5%|▌         | 5/100 [02:08<40:44, 25.73s/it]
# Generating backdoor for class 0:   6%|▌         | 6/100 [02:34<40:14, 25.68s/it]
# Generating backdoor for class 0:   7%|▋         | 7/100 [03:00<39:52, 25.73s/it]
# Generating backdoor for class 0:   8%|▊         | 8/100 [03:26<39:30, 25.77s/it]
# Generating backdoor for class 0:   9%|▉         | 9/100 [03:52<39:10, 25.83s/it]
# Generating backdoor for class 0:  10%|█         | 10/100 [04:17<38:45, 25.84s/it]
# Generating backdoor for class 0:  11%|█         | 11/100 [04:44<38:28, 25.93s/it]
# Generating backdoor for class 0:  12%|█▏        | 12/100 [05:10<38:09, 26.02s/it]
# Generating backdoor for class 0:  13%|█▎        | 13/100 [05:36<37:42, 26.01s/it]
# Generating backdoor for class 0:  14%|█▍        | 14/100 [06:02<37:20, 26.05s/it]
# Generating backdoor for class 0:  15%|█▌        | 15/100 [06:28<36:56, 26.07s/it]
# Generating backdoor for class 0:  16%|█▌        | 16/100 [06:54<36:32, 26.10s/it]
# Generating backdoor for class 0:  17%|█▋        | 17/100 [07:20<36:07, 26.11s/it]
# Generating backdoor for class 0:  18%|█▊        | 18/100 [07:46<35:34, 26.04s/it]
# Generating backdoor for class 0:  19%|█▉        | 19/100 [08:12<34:58, 25.91s/it]
# Generating backdoor for class 0:  20%|██        | 20/100 [08:41<35:40, 26.76s/it]
# Generating backdoor for class 0:  21%|██        | 21/100 [09:07<34:55, 26.53s/it]
# Generating backdoor for class 0:  22%|██▏       | 22/100 [09:32<34:15, 26.35s/it]
# Generating backdoor for class 0:  23%|██▎       | 23/100 [09:58<33:39, 26.22s/it]
# Generating backdoor for class 0:  24%|██▍       | 24/100 [10:25<33:09, 26.18s/it]
# Generating backdoor for class 0:  25%|██▌       | 25/100 [10:51<32:42, 26.16s/it]
# Generating backdoor for class 0:  26%|██▌       | 26/100 [11:17<32:15, 26.16s/it]
# Generating backdoor for class 0:  27%|██▋       | 27/100 [11:43<31:49, 26.15s/it]
# Generating backdoor for class 0:  28%|██▊       | 28/100 [12:09<31:21, 26.14s/it]
# Generating backdoor for class 0:  29%|██▉       | 29/100 [12:35<30:48, 26.04s/it]
# Generating backdoor for class 0:  30%|███       | 30/100 [13:01<30:20, 26.00s/it]
# Generating backdoor for class 0:  31%|███       | 31/100 [13:27<29:54, 26.01s/it]
# Generating backdoor for class 0:  32%|███▏      | 32/100 [13:53<29:33, 26.09s/it]
# Generating backdoor for class 0:  33%|███▎      | 33/100 [14:19<29:02, 26.00s/it]
# Generating backdoor for class 0:  34%|███▍      | 34/100 [14:45<28:34, 25.98s/it]
# Generating backdoor for class 0:  35%|███▌      | 35/100 [15:11<28:04, 25.92s/it]
# Generating backdoor for class 0:  36%|███▌      | 36/100 [15:36<27:38, 25.91s/it]
# Generating backdoor for class 0:  37%|███▋      | 37/100 [16:02<27:07, 25.83s/it]
# Generating backdoor for class 0:  38%|███▊      | 38/100 [16:28<26:40, 25.81s/it]
# Generating backdoor for class 0:  39%|███▉      | 39/100 [16:54<26:15, 25.82s/it]
# Generating backdoor for class 0:  40%|████      | 40/100 [17:19<25:45, 25.76s/it]
# Generating backdoor for class 0:  41%|████      | 41/100 [17:45<25:18, 25.73s/it]
# Generating backdoor for class 0:  42%|████▏     | 42/100 [18:10<24:48, 25.66s/it]
# Generating backdoor for class 0:  43%|████▎     | 43/100 [18:36<24:20, 25.63s/it]
# Generating backdoor for class 0:  44%|████▍     | 44/100 [19:05<24:49, 26.59s/it]
# Generating backdoor for class 0:  45%|████▌     | 45/100 [19:31<24:07, 26.32s/it]
# Generating backdoor for class 0:  46%|████▌     | 46/100 [19:56<23:29, 26.11s/it]
# Generating backdoor for class 0:  47%|████▋     | 47/100 [20:22<22:55, 25.96s/it]
# Generating backdoor for class 0:  48%|████▊     | 48/100 [20:47<22:24, 25.86s/it]
# Generating backdoor for class 0:  49%|████▉     | 49/100 [21:13<21:52, 25.74s/it]
# Generating backdoor for class 0:  50%|█████     | 50/100 [21:38<21:22, 25.65s/it]
# Generating backdoor for class 0:  51%|█████     | 51/100 [22:04<20:53, 25.57s/it]
# Generating backdoor for class 0:  52%|█████▏    | 52/100 [22:29<20:25, 25.53s/it]
# Generating backdoor for class 0:  53%|█████▎    | 53/100 [22:55<19:59, 25.52s/it]
# Generating backdoor for class 0:  54%|█████▍    | 54/100 [23:20<19:33, 25.51s/it]
# Generating backdoor for class 0:  55%|█████▌    | 55/100 [23:46<19:07, 25.50s/it]
# Generating backdoor for class 0:  56%|█████▌    | 56/100 [24:11<18:43, 25.53s/it]
# Generating backdoor for class 0:  57%|█████▋    | 57/100 [24:37<18:17, 25.52s/it]
# Generating backdoor for class 0:  58%|█████▊    | 58/100 [25:02<17:51, 25.52s/it]
# Generating backdoor for class 0:  59%|█████▉    | 59/100 [25:28<17:28, 25.58s/it]
# Generating backdoor for class 0:  60%|██████    | 60/100 [25:54<17:04, 25.62s/it]
# Generating backdoor for class 0:  61%|██████    | 61/100 [26:19<16:38, 25.61s/it]
# Generating backdoor for class 0:  62%|██████▏   | 62/100 [26:45<16:17, 25.73s/it]
# Generating backdoor for class 0:  63%|██████▎   | 63/100 [27:11<15:53, 25.76s/it]
# Generating backdoor for class 0:  64%|██████▍   | 64/100 [27:37<15:28, 25.78s/it]
# Generating backdoor for class 0:  65%|██████▌   | 65/100 [28:03<15:03, 25.81s/it]
# Generating backdoor for class 0:  66%|██████▌   | 66/100 [28:28<14:36, 25.77s/it]
# Generating backdoor for class 0:  67%|██████▋   | 67/100 [28:57<14:38, 26.63s/it]
# Generating backdoor for class 0:  68%|██████▊   | 68/100 [29:23<14:05, 26.41s/it]
# Generating backdoor for class 0:  69%|██████▉   | 69/100 [29:49<13:33, 26.24s/it]
# Generating backdoor for class 0:  70%|███████   | 70/100 [30:15<13:02, 26.07s/it]
# Generating backdoor for class 0:  71%|███████   | 71/100 [30:40<12:33, 25.99s/it]
# Generating backdoor for class 0:  72%|███████▏  | 72/100 [31:06<12:06, 25.95s/it]
# Generating backdoor for class 0:  73%|███████▎  | 73/100 [31:32<11:39, 25.92s/it]
# Generating backdoor for class 0:  74%|███████▍  | 74/100 [31:58<11:13, 25.89s/it]
# Generating backdoor for class 0:  75%|███████▌  | 75/100 [32:24<10:46, 25.85s/it]
# Generating backdoor for class 0:  76%|███████▌  | 76/100 [32:49<10:19, 25.80s/it]
# Generating backdoor for class 0:  77%|███████▋  | 77/100 [33:15<09:52, 25.74s/it]
# Generating backdoor for class 0:  78%|███████▊  | 78/100 [33:41<09:26, 25.75s/it]
# Generating backdoor for class 0:  79%|███████▉  | 79/100 [34:06<09:00, 25.75s/it]
# Generating backdoor for class 0:  80%|████████  | 80/100 [34:32<08:36, 25.85s/it]
# Generating backdoor for class 0:  81%|████████  | 81/100 [34:58<08:11, 25.86s/it]
# Generating backdoor for class 0:  82%|████████▏ | 82/100 [35:24<07:44, 25.82s/it]
# Generating backdoor for class 0:  83%|████████▎ | 83/100 [35:50<07:19, 25.86s/it]
# Generating backdoor for class 0:  84%|████████▍ | 84/100 [36:16<06:53, 25.86s/it]
# Generating backdoor for class 0:  85%|████████▌ | 85/100 [36:42<06:27, 25.87s/it]
# Generating backdoor for class 0:  86%|████████▌ | 86/100 [37:08<06:02, 25.89s/it]
# Generating backdoor for class 0:  87%|████████▋ | 87/100 [37:34<05:36, 25.89s/it]
# Generating backdoor for class 0:  88%|████████▊ | 88/100 [38:00<05:10, 25.90s/it]
# Generating backdoor for class 0:  89%|████████▉ | 89/100 [38:25<04:43, 25.81s/it]
# Generating backdoor for class 0:  90%|█████████ | 90/100 [38:51<04:17, 25.78s/it]
# Generating backdoor for class 0:  91%|█████████ | 91/100 [39:19<03:59, 26.61s/it]
# Generating backdoor for class 0:  92%|█████████▏| 92/100 [39:45<03:31, 26.38s/it]
# Generating backdoor for class 0:  93%|█████████▎| 93/100 [40:11<03:03, 26.25s/it]
# Generating backdoor for class 0:  94%|█████████▍| 94/100 [40:37<02:36, 26.17s/it]
# Generating backdoor for class 0:  95%|█████████▌| 95/100 [41:04<02:11, 26.23s/it]
# Generating backdoor for class 0:  96%|█████████▌| 96/100 [41:30<01:44, 26.23s/it]
# Generating backdoor for class 0:  97%|█████████▋| 97/100 [41:56<01:18, 26.23s/it]
# Generating backdoor for class 0:  98%|█████████▊| 98/100 [42:22<00:52, 26.22s/it]
# Generating backdoor for class 0:  99%|█████████▉| 99/100 [42:48<00:26, 26.19s/it]
# Generating backdoor for class 0: 100%|██████████| 100/100 [43:14<00:00, 25.95s/it]
#
# Generating backdoor for class 0:   0%|          | 0/100 [00:00<?, ?it/s]
# Generating backdoor for class 0:   1%|          | 1/100 [00:26<43:01, 26.08s/it]
# Generating backdoor for class 0:   2%|▏         | 2/100 [00:52<42:35, 26.07s/it]
# Generating backdoor for class 0:   3%|▎         | 3/100 [01:18<42:11, 26.10s/it]
# Generating backdoor for class 0:   4%|▍         | 4/100 [01:44<41:54, 26.19s/it]
# Generating backdoor for class 0:   5%|▌         | 5/100 [02:10<41:19, 26.11s/it]
# Generating backdoor for class 0:   6%|▌         | 6/100 [02:36<40:55, 26.13s/it]
# Generating backdoor for class 0:   7%|▋         | 7/100 [03:02<40:27, 26.10s/it]
# Generating backdoor for class 0:   8%|▊         | 8/100 [03:28<40:01, 26.11s/it]
# Generating backdoor for class 0:   9%|▉         | 9/100 [03:55<39:41, 26.17s/it]
# Generating backdoor for class 0:  10%|█         | 10/100 [04:21<39:10, 26.12s/it]
# Generating backdoor for class 0:  11%|█         | 11/100 [04:47<38:39, 26.06s/it]
# Generating backdoor for class 0:  12%|█▏        | 12/100 [05:13<38:10, 26.02s/it]
# Generating backdoor for class 0:  13%|█▎        | 13/100 [05:39<37:43, 26.02s/it]
# Generating backdoor for class 0:  14%|█▍        | 14/100 [06:07<38:29, 26.85s/it]
# Generating backdoor for class 0:  15%|█▌        | 15/100 [06:33<37:39, 26.59s/it]
# Generating backdoor for class 0:  16%|█▌        | 16/100 [07:00<37:03, 26.47s/it]
# Generating backdoor for class 0:  17%|█▋        | 17/100 [07:26<36:30, 26.39s/it]
# Generating backdoor for class 0:  18%|█▊        | 18/100 [07:52<36:00, 26.34s/it]
# Generating backdoor for class 0:  19%|█▉        | 19/100 [08:18<35:30, 26.30s/it]
# Generating backdoor for class 0:  20%|██        | 20/100 [08:45<35:03, 26.30s/it]
# Generating backdoor for class 0:  21%|██        | 21/100 [09:11<34:40, 26.34s/it]
# Generating backdoor for class 0:  22%|██▏       | 22/100 [09:37<34:16, 26.37s/it]
# Generating backdoor for class 0:  23%|██▎       | 23/100 [10:04<33:52, 26.39s/it]
# Generating backdoor for class 0:  24%|██▍       | 24/100 [10:30<33:25, 26.39s/it]
# Generating backdoor for class 0:  25%|██▌       | 25/100 [10:57<32:59, 26.39s/it]
# Generating backdoor for class 0:  26%|██▌       | 26/100 [11:23<32:33, 26.40s/it]
# Generating backdoor for class 0:  27%|██▋       | 27/100 [11:49<32:06, 26.38s/it]
# Generating backdoor for class 0:  28%|██▊       | 28/100 [12:16<31:41, 26.41s/it]
# Generating backdoor for class 0:  29%|██▉       | 29/100 [12:42<31:12, 26.37s/it]
# Generating backdoor for class 0:  30%|███       | 30/100 [13:08<30:44, 26.35s/it]
# Generating backdoor for class 0:  31%|███       | 31/100 [13:35<30:14, 26.30s/it]
# Generating backdoor for class 0:  32%|███▏      | 32/100 [14:01<29:46, 26.27s/it]
# Generating backdoor for class 0:  33%|███▎      | 33/100 [14:27<29:18, 26.24s/it]
# Generating backdoor for class 0:  34%|███▍      | 34/100 [14:53<28:49, 26.20s/it]
# Generating backdoor for class 0:  35%|███▌      | 35/100 [15:19<28:21, 26.17s/it]
# Generating backdoor for class 0:  36%|███▌      | 36/100 [15:45<27:55, 26.18s/it]
# Generating backdoor for class 0:  37%|███▋      | 37/100 [16:15<28:24, 27.06s/it]
# Generating backdoor for class 0:  38%|███▊      | 38/100 [16:41<27:42, 26.81s/it]
# Generating backdoor for class 0:  39%|███▉      | 39/100 [17:07<27:06, 26.67s/it]
# Generating backdoor for class 0:  40%|████      | 40/100 [17:33<26:33, 26.55s/it]
# Generating backdoor for class 0:  41%|████      | 41/100 [18:00<26:04, 26.51s/it]
# Generating backdoor for class 0:  42%|████▏     | 42/100 [18:26<25:33, 26.45s/it]
# Generating backdoor for class 0:  43%|████▎     | 43/100 [18:52<25:03, 26.38s/it]
# Generating backdoor for class 0:  44%|████▍     | 44/100 [19:19<24:34, 26.33s/it]
# Generating backdoor for class 0:  45%|████▌     | 45/100 [19:45<24:06, 26.29s/it]
# Generating backdoor for class 0:  46%|████▌     | 46/100 [20:11<23:38, 26.27s/it]
# Generating backdoor for class 0:  47%|████▋     | 47/100 [20:37<23:10, 26.24s/it]
# Generating backdoor for class 0:  48%|████▊     | 48/100 [21:03<22:44, 26.24s/it]
# Generating backdoor for class 0:  49%|████▉     | 49/100 [21:30<22:18, 26.25s/it]
# Generating backdoor for class 0:  50%|█████     | 50/100 [21:56<21:52, 26.24s/it]
# Generating backdoor for class 0:  51%|█████     | 51/100 [22:22<21:28, 26.30s/it]
# Generating backdoor for class 0:  52%|█████▏    | 52/100 [22:49<21:01, 26.29s/it]
# Generating backdoor for class 0:  53%|█████▎    | 53/100 [23:15<20:36, 26.30s/it]
# Generating backdoor for class 0:  54%|█████▍    | 54/100 [23:41<20:09, 26.29s/it]
# Generating backdoor for class 0:  55%|█████▌    | 55/100 [24:08<19:44, 26.32s/it]
# Generating backdoor for class 0:  56%|█████▌    | 56/100 [24:34<19:16, 26.28s/it]
# Generating backdoor for class 0:  57%|█████▋    | 57/100 [25:00<18:48, 26.25s/it]
# Generating backdoor for class 0:  58%|█████▊    | 58/100 [25:26<18:22, 26.24s/it]
# Generating backdoor for class 0:  59%|█████▉    | 59/100 [25:52<17:55, 26.24s/it]
# Generating backdoor for class 0:  60%|██████    | 60/100 [26:22<18:04, 27.12s/it]
# Generating backdoor for class 0:  61%|██████    | 61/100 [26:48<17:27, 26.87s/it]
# Generating backdoor for class 0:  62%|██████▏   | 62/100 [27:14<16:53, 26.67s/it]
# Generating backdoor for class 0:  63%|██████▎   | 63/100 [27:40<16:23, 26.57s/it]
# Generating backdoor for class 0:  64%|██████▍   | 64/100 [28:07<15:52, 26.45s/it]
# Generating backdoor for class 0:  65%|██████▌   | 65/100 [28:33<15:24, 26.40s/it]
# Generating backdoor for class 0:  66%|██████▌   | 66/100 [28:59<14:55, 26.34s/it]
# Generating backdoor for class 0:  67%|██████▋   | 67/100 [29:25<14:27, 26.29s/it]
# Generating backdoor for class 0:  68%|██████▊   | 68/100 [29:51<14:00, 26.26s/it]
# Generating backdoor for class 0:  69%|██████▉   | 69/100 [30:18<13:34, 26.26s/it]
# Generating backdoor for class 0:  70%|███████   | 70/100 [30:44<13:06, 26.21s/it]
# Generating backdoor for class 0:  71%|███████   | 71/100 [31:10<12:40, 26.21s/it]
# Generating backdoor for class 0:  72%|███████▏  | 72/100 [31:36<12:14, 26.22s/it]
# Generating backdoor for class 0:  73%|███████▎  | 73/100 [32:02<11:47, 26.20s/it]
# Generating backdoor for class 0:  74%|███████▍  | 74/100 [32:28<11:20, 26.18s/it]
# Generating backdoor for class 0:  75%|███████▌  | 75/100 [32:55<10:56, 26.24s/it]
# Generating backdoor for class 0:  76%|███████▌  | 76/100 [33:21<10:29, 26.23s/it]
# Generating backdoor for class 0:  77%|███████▋  | 77/100 [33:47<10:03, 26.22s/it]
# Generating backdoor for class 0:  78%|███████▊  | 78/100 [34:13<09:35, 26.17s/it]
# Generating backdoor for class 0:  79%|███████▉  | 79/100 [34:39<09:09, 26.17s/it]
# Generating backdoor for class 0:  80%|████████  | 80/100 [35:06<08:43, 26.15s/it]
# ...
# Generating backdoor for class 0:   7%|▋         | 7/100 [03:03<40:36, 26.20s/it]
# Generating backdoor for class 0:   8%|▊         | 8/100 [03:29<40:06, 26.16s/it]
# Generating backdoor for class 0:   9%|▉         | 9/100 [03:55<39:36, 26.12s/it]
# Generating backdoor for class 0:  10%|█         | 10/100 [04:21<39:12, 26.14s/it]
# Generating backdoor for class 0:  11%|█         | 11/100 [04:47<38:46, 26.14s/it]
# Generating backdoor for class 0:  12%|█▏        | 12/100 [05:14<38:27, 26.22s/it]
# Generating backdoor for class 0:  13%|█▎        | 13/100 [05:40<37:59, 26.20s/it]
# Generating backdoor for class 0:  14%|█▍        | 14/100 [06:06<37:26, 26.13s/it]
# Generating backdoor for class 0:  15%|█▌        | 15/100 [06:32<36:59, 26.12s/it]
# Generating backdoor for class 0:  16%|█▌        | 16/100 [07:01<37:48, 27.00s/it]
# Generating backdoor for class 0:  17%|█▋        | 17/100 [07:28<37:11, 26.88s/it]
# Generating backdoor for class 0:  18%|█▊        | 18/100 [07:54<36:40, 26.83s/it]
# Generating backdoor for class 0:  19%|█▉        | 19/100 [08:21<35:55, 26.61s/it]
# Generating backdoor for class 0:  20%|██        | 20/100 [08:46<35:12, 26.41s/it]
# Generating backdoor for class 0:  21%|██        | 21/100 [09:13<34:37, 26.30s/it]
# Generating backdoor for class 0:  22%|██▏       | 22/100 [09:38<34:01, 26.18s/it]
# Generating backdoor for class 0:  23%|██▎       | 23/100 [10:04<33:29, 26.09s/it]
# Generating backdoor for class 0:  24%|██▍       | 24/100 [10:31<33:09, 26.18s/it]
# Generating backdoor for class 0:  25%|██▌       | 25/100 [10:57<32:40, 26.14s/it]
# Generating backdoor for class 0:  26%|██▌       | 26/100 [11:23<32:10, 26.09s/it]
# Generating backdoor for class 0:  27%|██▋       | 27/100 [11:49<31:41, 26.05s/it]
# Generating backdoor for class 0:  28%|██▊       | 28/100 [12:15<31:11, 26.00s/it]
# Generating backdoor for class 0:  29%|██▉       | 29/100 [12:41<30:46, 26.01s/it]
# Generating backdoor for class 0:  30%|███       | 30/100 [13:07<30:20, 26.01s/it]
# Generating backdoor for class 0:  31%|███       | 31/100 [13:32<29:51, 25.96s/it]
# Generating backdoor for class 0:  32%|███▏      | 32/100 [13:58<29:20, 25.89s/it]
# Generating backdoor for class 0:  33%|███▎      | 33/100 [14:24<28:57, 25.94s/it]
# Generating backdoor for class 0:  34%|███▍      | 34/100 [14:50<28:30, 25.91s/it]
# Generating backdoor for class 0:  35%|███▌      | 35/100 [15:16<28:06, 25.95s/it]
# Generating backdoor for class 0:  36%|███▌      | 36/100 [15:43<27:50, 26.10s/it]
# Generating backdoor for class 0:  37%|███▋      | 37/100 [16:09<27:27, 26.16s/it]
# Generating backdoor for class 0:  38%|███▊      | 38/100 [16:35<27:06, 26.24s/it]
# Generating backdoor for class 0:  39%|███▉      | 39/100 [17:04<27:21, 26.90s/it]
# Generating backdoor for class 0:  40%|████      | 40/100 [17:32<27:12, 27.20s/it]
# Generating backdoor for class 0:  41%|████      | 41/100 [17:58<26:34, 27.03s/it]
# Generating backdoor for class 0:  42%|████▏     | 42/100 [18:25<25:54, 26.80s/it]
# Generating backdoor for class 0:  43%|████▎     | 43/100 [18:51<25:22, 26.70s/it]
# Generating backdoor for class 0:  44%|████▍     | 44/100 [19:18<24:55, 26.70s/it]
# Generating backdoor for class 0:  45%|████▌     | 45/100 [19:44<24:27, 26.68s/it]
# Generating backdoor for class 0:  46%|████▌     | 46/100 [20:11<24:03, 26.73s/it]
# Generating backdoor for class 0:  47%|████▋     | 47/100 [20:38<23:38, 26.76s/it]
# Generating backdoor for class 0:  48%|████▊     | 48/100 [21:05<23:08, 26.69s/it]
# Generating backdoor for class 0:  49%|████▉     | 49/100 [21:31<22:35, 26.58s/it]
# Generating backdoor for class 0:  50%|█████     | 50/100 [21:57<22:06, 26.53s/it]
# Generating backdoor for class 0:  51%|█████     | 51/100 [22:24<21:41, 26.56s/it]
# Generating backdoor for class 0:  52%|█████▏    | 52/100 [22:50<21:11, 26.49s/it]
# Generating backdoor for class 0:  53%|█████▎    | 53/100 [23:17<20:43, 26.45s/it]
# Generating backdoor for class 0:  54%|█████▍    | 54/100 [23:43<20:21, 26.55s/it]
# Generating backdoor for class 0:  55%|█████▌    | 55/100 [24:10<19:58, 26.63s/it]
# Generating backdoor for class 0:  56%|█████▌    | 56/100 [24:38<19:41, 26.84s/it]
# Generating backdoor for class 0:  57%|█████▋    | 57/100 [25:04<19:12, 26.80s/it]
# Generating backdoor for class 0:  58%|█████▊    | 58/100 [25:31<18:42, 26.71s/it]
# Generating backdoor for class 0:  59%|█████▉    | 59/100 [25:58<18:15, 26.72s/it]
# Generating backdoor for class 0:  60%|██████    | 60/100 [26:24<17:49, 26.75s/it]
# Generating backdoor for class 0:  61%|██████    | 61/100 [26:51<17:20, 26.68s/it]
# Generating backdoor for class 0:  62%|██████▏   | 62/100 [27:21<17:29, 27.62s/it]
# Generating backdoor for class 0:  63%|██████▎   | 63/100 [27:47<16:51, 27.34s/it]
# Generating backdoor for class 0:  64%|██████▍   | 64/100 [28:14<16:19, 27.20s/it]
# Generating backdoor for class 0:  65%|██████▌   | 65/100 [28:41<15:47, 27.08s/it]
# Generating backdoor for class 0:  66%|██████▌   | 66/100 [29:08<15:19, 27.03s/it]
# Generating backdoor for class 0:  67%|██████▋   | 67/100 [29:35<14:53, 27.08s/it]
# Generating backdoor for class 0:  68%|██████▊   | 68/100 [30:02<14:22, 26.94s/it]
# Generating backdoor for class 0:  69%|██████▉   | 69/100 [30:28<13:53, 26.88s/it]
# Generating backdoor for class 0:  70%|███████   | 70/100 [30:55<13:27, 26.92s/it]
# Generating backdoor for class 0:  71%|███████   | 71/100 [31:23<13:01, 26.96s/it]
# Generating backdoor for class 0:  72%|███████▏  | 72/100 [31:49<12:34, 26.94s/it]
# Generating backdoor for class 0:  73%|███████▎  | 73/100 [32:16<12:06, 26.89s/it]
# Generating backdoor for class 0:  74%|███████▍  | 74/100 [32:43<11:41, 26.96s/it]
# Generating backdoor for class 0:  75%|███████▌  | 75/100 [33:10<11:15, 27.01s/it]
# Generating backdoor for class 0:  76%|███████▌  | 76/100 [33:38<10:48, 27.02s/it]
# Generating backdoor for class 0:  77%|███████▋  | 77/100 [34:05<10:22, 27.04s/it]
# Generating backdoor for class 0:  78%|███████▊  | 78/100 [34:32<09:55, 27.07s/it]
# Generating backdoor for class 0:  79%|███████▉  | 79/100 [34:59<09:29, 27.12s/it]
# Generating backdoor for class 0:  80%|████████  | 80/100 [35:26<09:02, 27.12s/it]
# Generating backdoor for class 0:  81%|████████  | 81/100 [35:53<08:34, 27.10s/it]
# Generating backdoor for class 0:  82%|████████▏ | 82/100 [36:21<08:09, 27.18s/it]
# Generating backdoor for class 0:  83%|████████▎ | 83/100 [36:47<07:40, 27.11s/it]
# Generating backdoor for class 0:  84%|████████▍ | 84/100 [37:14<07:10, 26.92s/it]
# Generating backdoor for class 0:  85%|████████▌ | 85/100 [37:43<06:53, 27.59s/it]
# Generating backdoor for class 0:  86%|████████▌ | 86/100 [38:09<06:20, 27.18s/it]
# Generating backdoor for class 0:  87%|████████▋ | 87/100 [38:36<05:51, 27.04s/it]
# Generating backdoor for class 0:  88%|████████▊ | 88/100 [39:03<05:24, 27.02s/it]
# Generating backdoor for class 0:  89%|████████▉ | 89/100 [39:30<04:57, 27.01s/it]
# Generating backdoor for class 0:  90%|█████████ | 90/100 [39:57<04:29, 26.97s/it]
# Generating backdoor for class 0:  91%|█████████ | 91/100 [40:24<04:02, 26.96s/it]
# Generating backdoor for class 0:  92%|█████████▏| 92/100 [40:51<03:35, 26.91s/it]
# Generating backdoor for class 0:  93%|█████████▎| 93/100 [41:17<03:07, 26.79s/it]
# Generating backdoor for class 0:  94%|█████████▍| 94/100 [41:44<02:40, 26.68s/it]
# Generating backdoor for class 0:  95%|█████████▌| 95/100 [42:10<02:12, 26.56s/it]
# Generating backdoor for class 0:  96%|█████████▌| 96/100 [42:36<01:45, 26.50s/it]
# Generating backdoor for class 0:  97%|█████████▋| 97/100 [43:03<01:19, 26.49s/it]
# Generating backdoor for class 0:  98%|█████████▊| 98/100 [43:30<00:53, 26.64s/it]
# Generating backdoor for class 0:  99%|█████████▉| 99/100 [43:56<00:26, 26.69s/it]
# Generating backdoor for class 0: 100%|██████████| 100/100 [44:23<00:00, 26.64s/it]
#
# Generating backdoor for class 0:   0%|          | 0/100 [00:00<?, ?it/s]
# Generating backdoor for class 0:   1%|          | 1/100 [00:27<45:01, 27.29s/it]
# Generating backdoor for class 0:   2%|▏         | 2/100 [00:54<44:34, 27.29s/it]
# Generating backdoor for class 0:   3%|▎         | 3/100 [01:21<43:53, 27.15s/it]
# Generating backdoor for class 0:   4%|▍         | 4/100 [01:48<43:13, 27.01s/it]
# Generating backdoor for class 0:   5%|▌         | 5/100 [02:14<42:41, 26.96s/it]
# Generating backdoor for class 0:   6%|▌         | 6/100 [02:41<41:59, 26.80s/it]
# Generating backdoor for class 0:   7%|▋         | 7/100 [03:08<41:39, 26.87s/it]
# Generating backdoor for class 0:   8%|▊         | 8/100 [03:36<41:56, 27.35s/it]
# Generating backdoor for class 0:   9%|▉         | 9/100 [04:03<40:57, 27.00s/it]
# Generating backdoor for class 0:  10%|█         | 10/100 [04:29<40:07, 26.75s/it]
# Generating backdoor for class 0:  11%|█         | 11/100 [04:55<39:25, 26.58s/it]
# Generating backdoor for class 0:  12%|█▏        | 12/100 [05:21<38:39, 26.36s/it]
# Generating backdoor for class 0:  13%|█▎        | 13/100 [05:47<38:10, 26.33s/it]
# Generating backdoor for class 0:  14%|█▍        | 14/100 [06:14<37:52, 26.42s/it]
# Generating backdoor for class 0:  15%|█▌        | 15/100 [06:40<37:18, 26.34s/it]
# Generating backdoor for class 0:  16%|█▌        | 16/100 [07:06<36:44, 26.24s/it]
# Generating backdoor for class 0:  17%|█▋        | 17/100 [07:32<36:14, 26.20s/it]
# Generating backdoor for class 0:  18%|█▊        | 18/100 [07:58<35:40, 26.10s/it]
# Generating backdoor for class 0:  19%|█▉        | 19/100 [08:24<35:11, 26.06s/it]
# Generating backdoor for class 0:  20%|██        | 20/100 [08:50<34:44, 26.06s/it]
# Generating backdoor for class 0:  21%|██        | 21/100 [09:16<34:11, 25.97s/it]
# Generating backdoor for class 0:  22%|██▏       | 22/100 [09:41<33:37, 25.86s/it]
# Generating backdoor for class 0:  23%|██▎       | 23/100 [10:07<33:06, 25.80s/it]
# Generating backdoor for class 0:  24%|██▍       | 24/100 [10:33<32:41, 25.80s/it]
# Generating backdoor for class 0:  25%|██▌       | 25/100 [10:58<32:15, 25.81s/it]
# Generating backdoor for class 0:  26%|██▌       | 26/100 [11:24<31:45, 25.75s/it]
# Generating backdoor for class 0:  27%|██▋       | 27/100 [11:50<31:17, 25.72s/it]
# Generating backdoor for class 0:  28%|██▊       | 28/100 [12:15<30:50, 25.70s/it]
# Generating backdoor for class 0:  29%|██▉       | 29/100 [12:41<30:27, 25.74s/it]
# Generating backdoor for class 0:  30%|███       | 30/100 [13:07<30:03, 25.77s/it]
# Generating backdoor for class 0:  31%|███       | 31/100 [13:36<30:35, 26.61s/it]
# Generating backdoor for class 0:  32%|███▏      | 32/100 [14:02<29:57, 26.43s/it]
# Generating backdoor for class 0:  33%|███▎      | 33/100 [14:28<29:21, 26.28s/it]
# Generating backdoor for class 0:  34%|███▍      | 34/100 [14:54<28:54, 26.28s/it]
# Generating backdoor for class 0:  35%|███▌      | 35/100 [15:20<28:19, 26.15s/it]
# Generating backdoor for class 0:  36%|███▌      | 36/100 [15:46<27:50, 26.10s/it]
# Generating backdoor for class 0:  37%|███▋      | 37/100 [16:12<27:24, 26.10s/it]
# Generating backdoor for class 0:  38%|███▊      | 38/100 [16:38<26:58, 26.10s/it]
# Generating backdoor for class 0:  39%|███▉      | 39/100 [17:04<26:31, 26.09s/it]
# Generating backdoor for class 0:  40%|████      | 40/100 [17:30<26:03, 26.06s/it]
# Generating backdoor for class 0:  41%|████      | 41/100 [17:56<25:39, 26.09s/it]
# Generating backdoor for class 0:  42%|████▏     | 42/100 [18:22<25:12, 26.08s/it]
# Generating backdoor for class 0:  43%|████▎     | 43/100 [18:48<24:44, 26.04s/it]
# Generating backdoor for class 0:  44%|████▍     | 44/100 [19:14<24:20, 26.08s/it]
# Generating backdoor for class 0:  45%|████▌     | 45/100 [19:40<23:53, 26.07s/it]
# Generating backdoor for class 0:  46%|████▌     | 46/100 [20:06<23:27, 26.07s/it]
# Generating backdoor for class 0:  47%|████▋     | 47/100 [20:32<23:01, 26.06s/it]
# Generating backdoor for class 0:  48%|████▊     | 48/100 [20:59<22:37, 26.11s/it]
# Generating backdoor for class 0:  49%|████▉     | 49/100 [21:25<22:11, 26.10s/it]
# Generating backdoor for class 0:  50%|█████     | 50/100 [21:51<21:43, 26.08s/it]
# Generating backdoor for class 0:  51%|█████     | 51/100 [22:17<21:16, 26.05s/it]
# Generating backdoor for class 0:  52%|█████▏    | 52/100 [22:43<20:49, 26.03s/it]
# Generating backdoor for class 0:  53%|█████▎    | 53/100 [23:09<20:26, 26.09s/it]
# Generating backdoor for class 0:  54%|█████▍    | 54/100 [23:38<20:40, 26.96s/it]
# Generating backdoor for class 0:  55%|█████▌    | 55/100 [24:04<20:01, 26.69s/it]
# Generating backdoor for class 0:  56%|█████▌    | 56/100 [24:30<19:26, 26.50s/it]
# Generating backdoor for class 0:  57%|█████▋    | 57/100 [24:56<18:53, 26.36s/it]
# Generating backdoor for class 0:  58%|█████▊    | 58/100 [25:22<18:23, 26.28s/it]
# Generating backdoor for class 0:  59%|█████▉    | 59/100 [25:48<17:53, 26.18s/it]
# Generating backdoor for class 0:  60%|██████    | 60/100 [26:14<17:24, 26.12s/it]
# Generating backdoor for class 0:  61%|██████    | 61/100 [26:40<16:55, 26.03s/it]
# Generating backdoor for class 0:  62%|██████▏   | 62/100 [27:06<16:27, 25.97s/it]
# Generating backdoor for class 0:  63%|██████▎   | 63/100 [27:32<15:59, 25.93s/it]
# Generating backdoor for class 0:  64%|██████▍   | 64/100 [27:58<15:33, 25.93s/it]
# Generating backdoor for class 0:  65%|██████▌   | 65/100 [28:24<15:09, 25.98s/it]
# Generating backdoor for class 0:  66%|██████▌   | 66/100 [28:50<14:42, 25.96s/it]
# Generating backdoor for class 0:  67%|██████▋   | 67/100 [29:16<14:17, 25.99s/it]
# Generating backdoor for class 0:  68%|██████▊   | 68/100 [29:42<13:52, 26.02s/it]
# Generating backdoor for class 0:  69%|██████▉   | 69/100 [30:08<13:26, 26.02s/it]
# Generating backdoor for class 0:  70%|███████   | 70/100 [30:34<13:01, 26.04s/it]
# Generating backdoor for class 0:  71%|███████   | 71/100 [31:00<12:37, 26.14s/it]
# Generating backdoor for class 0:  72%|███████▏  | 72/100 [31:26<12:11, 26.13s/it]
# Generating backdoor for class 0:  73%|███████▎  | 73/100 [31:53<11:46, 26.16s/it]
# Generating backdoor for class 0:  74%|███████▍  | 74/100 [32:19<11:21, 26.20s/it]
# Generating backdoor for class 0:  75%|███████▌  | 75/100 [32:45<10:55, 26.23s/it]
# Generating backdoor for class 0:  76%|███████▌  | 76/100 [33:12<10:31, 26.32s/it]
# Generating backdoor for class 0:  77%|███████▋  | 77/100 [33:39<10:15, 26.77s/it]
# Generating backdoor for class 0:  78%|███████▊  | 78/100 [34:07<09:56, 27.09s/it]
# Generating backdoor for class 0:  79%|███████▉  | 79/100 [34:34<09:24, 26.89s/it]
# Generating backdoor for class 0:  80%|████████  | 80/100 [35:00<08:54, 26.72s/it]
# Generating backdoor for class 0:  81%|████████  | 81/100 [35:26<08:25, 26.61s/it]
# Generating backdoor for class 0:  82%|████████▏ | 82/100 [35:53<07:56, 26.50s/it]
# Generating backdoor for class 0:  83%|████████▎ | 83/100 [36:19<07:29, 26.44s/it]
# Generating backdoor for class 0:  84%|████████▍ | 84/100 [36:45<07:02, 26.38s/it]
# Generating backdoor for class 0:  85%|████████▌ | 85/100 [37:11<06:35, 26.34s/it]
# Generating backdoor for class 0:  86%|████████▌ | 86/100 [37:38<06:08, 26.35s/it]
# Generating backdoor for class 0:  87%|████████▋ | 87/100 [38:04<05:42, 26.34s/it]
# Generating backdoor for class 0:  88%|████████▊ | 88/100 [38:31<05:16, 26.38s/it]
# Generating backdoor for class 0:  89%|████████▉ | 89/100 [38:57<04:49, 26.36s/it]
# Generating backdoor for class 0:  90%|█████████ | 90/100 [39:23<04:23, 26.34s/it]
# Generating backdoor for class 0:  91%|█████████ | 91/100 [39:49<03:56, 26.32s/it]
# Generating backdoor for class 0:  92%|█████████▏| 92/100 [40:16<03:30, 26.32s/it]
# Generating backdoor for class 0:  93%|█████████▎| 93/100 [40:42<03:04, 26.36s/it]
# Generating backdoor for class 0:  94%|█████████▍| 94/100 [41:09<02:38, 26.41s/it]
# Generating backdoor for class 0:  95%|█████████▌| 95/100 [41:35<02:12, 26.41s/it]
# Generating backdoor for class 0:  96%|█████████▌| 96/100 [42:02<01:45, 26.40s/it]
# Generating backdoor for class 0:  97%|█████████▋| 97/100 [42:28<01:19, 26.42s/it]
# Generating backdoor for class 0:  98%|█████████▊| 98/100 [42:54<00:52, 26.40s/it]
# Generating backdoor for class 0:  99%|█████████▉| 99/100 [43:21<00:26, 26.38s/it]
# Generating backdoor for class 0: 100%|██████████| 100/100 [43:48<00:00, 26.28s/it]

# %%
model_name, _ = MODEL_FILE.split('.')
np.save(os.path.join('/content/drive/MyDrive/ML4Cyber/data','mask_{}.npy'.format(model_name)), mask)
np.save('pattern_{}.npy'.format(model_name), pattern)

# %%
a = np.array([])
b = np.array([2, 3])
a = np.append(a,b)

# %%
a
# Out:
# array([2., 3.])
